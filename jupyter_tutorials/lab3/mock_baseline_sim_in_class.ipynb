# %%
import ugradio
import numpy as np
import matplotlib.pyplot as plt
import glob
from scipy.special import j1
# %matplotlib notebook

# %%
jd = 2460025
NTIMES = 2**20
FREQ = 10.5e9  # Hz
C = 2.99e8  # m / s

# %%
jds = np.linspace(jd, jd+1, NTIMES)
lst0 = ugradio.timing.lst(jds[0])
lst1 = ugradio.timing.lst(jds[1])
lsts = lst0 + np.arange(NTIMES) * (lst1 - lst0)
ones = np.ones_like(lsts)
#ha = lsts - radec[0]
rot_eq_ha = np.array([[
    [np.cos(lsts),  np.sin(lsts),     0*ones],
    [np.sin(lsts), -np.cos(lsts),     0*ones],
    [      0*ones,        0*ones,     1*ones],
]])
lat = np.deg2rad(ugradio.nch.lat)
rot_ha_altaz = np.array([[
    [-np.sin(lat),  0, np.cos(lat)],
    [           0, -1,           0],
    [ np.cos(lat),  0, np.sin(lat)],
]])

rot_full = np.dot(rot_ha_altaz, rot_eq_ha)
rot_full.shape = (3, 3, -1)
#altazs = np.array([ugradio.coord.get_altaz(sun[0], sun[1], jd=tjd) for tjd in jds])
#altazs = np.deg2rad(altazs)

# %%
sun_radec = ugradio.coord.sunpos(jd)
radec = (np.deg2rad(sun_radec[0]), np.deg2rad(sun_radec[1]))
theta = np.pi/2 - radec[1]
phi = radec[0]
sun_z = np.cos(theta)
r_xy = np.sin(theta)
sun_x = r_xy * np.cos(phi)
sun_y = r_xy * np.sin(phi)
sun_pos_eq = np.array([sun_x, sun_y, sun_z])
sun_pos_top = np.dot(sun_pos_eq, rot_full)
sun_pos_top = np.array([sun_pos_top[1], sun_pos_top[0], sun_pos_top[2]])
sun_pos_top.shape
#sun_pos_top[0], sun_pos_top[1] = sun_pos_top[1], sun_pos_top[0]
# Out:
# (3, 1048576)

# %%
plt.figure()
plt.plot(jds, sun_pos_top[0])
plt.plot(jds, sun_pos_top[1])
plt.plot(jds, sun_pos_top[2])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
baseline = np.array([20., 2., 0])  # m
rsun = np.deg2rad(0.25)

# %%
b_proj = np.dot(baseline, sun_pos_top)
lam = C / FREQ
w = b_proj / lam
uv = np.sqrt(np.dot(baseline, baseline) - b_proj**2) / lam
x = 2 * np.pi * uv * rsun
bess = j1(x) / x
fringe = np.exp(-2*np.pi*1j*w)
fringe = np.where(sun_pos_top[2] > 0, bess*fringe, 0)

# %%
plt.figure()
plt.plot(jds, fringe)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data_files = sorted(glob.glob('sun_data/*.npy'))
print(data_files)
# Out:
# ['sun_data/sun_0.npy', 'sun_data/sun_1.npy', 'sun_data/sun_10.npy', 'sun_data/sun_100.npy', 'sun_data/sun_1000.npy', 'sun_data/sun_10000.npy', 'sun_data/sun_10001.npy', 'sun_data/sun_10002.npy', 'sun_data/sun_10003.npy', 'sun_data/sun_10004.npy', 'sun_data/sun_10005.npy', 'sun_data/sun_10006.npy', 'sun_data/sun_10007.npy', 'sun_data/sun_10008.npy', 'sun_data/sun_10009.npy', 'sun_data/sun_1001.npy', 'sun_data/sun_10010.npy', 'sun_data/sun_10011.npy', 'sun_data/sun_10012.npy', 'sun_data/sun_10013.npy', 'sun_data/sun_10014.npy', 'sun_data/sun_10015.npy', 'sun_data/sun_10016.npy', 'sun_data/sun_10017.npy', 'sun_data/sun_10018.npy', 'sun_data/sun_10019.npy', 'sun_data/sun_1002.npy', 'sun_data/sun_10020.npy', 'sun_data/sun_10021.npy', 'sun_data/sun_10022.npy', 'sun_data/sun_10023.npy', 'sun_data/sun_10024.npy', 'sun_data/sun_10025.npy', 'sun_data/sun_10026.npy', 'sun_data/sun_10027.npy', 'sun_data/sun_10028.npy', 'sun_data/sun_10029.npy', 'sun_data/sun_1003.npy', 'sun_data/sun_10030.npy', 'sun_data/sun_10031.npy', 'sun_data/sun_10032.npy', 'sun_data/sun_10033.npy', 'sun_data/sun_10034.npy', 'sun_data/sun_10035.npy', 'sun_data/sun_10036.npy', 'sun_data/sun_10037.npy', 'sun_data/sun_10038.npy', 'sun_data/sun_10039.npy', 'sun_data/sun_1004.npy', 'sun_data/sun_10040.npy', 'sun_data/sun_10041.npy', 'sun_data/sun_10042.npy', 'sun_data/sun_10043.npy', 'sun_data/sun_10044.npy', 'sun_data/sun_10045.npy', 'sun_data/sun_10046.npy', 'sun_data/sun_10047.npy', 'sun_data/sun_10048.npy', 'sun_data/sun_10049.npy', 'sun_data/sun_1005.npy', 'sun_data/sun_10050.npy', 'sun_data/sun_10051.npy', 'sun_data/sun_10052.npy', 'sun_data/sun_10053.npy', 'sun_data/sun_10054.npy', 'sun_data/sun_10055.npy', 'sun_data/sun_10056.npy', 'sun_data/sun_10057.npy', 'sun_data/sun_10058.npy', 'sun_data/sun_10059.npy', 'sun_data/sun_1006.npy', 'sun_data/sun_10060.npy', 'sun_data/sun_10061.npy', 'sun_data/sun_10062.npy', 'sun_data/sun_10063.npy', 'sun_data/sun_10064.npy', 'sun_data/sun_10065.npy', 'sun_data/sun_10066.npy', 'sun_data/sun_10067.npy', 'sun_data/sun_10068.npy', 'sun_data/sun_10069.npy', 'sun_data/sun_1007.npy', 'sun_data/sun_10070.npy', 'sun_data/sun_10071.npy', 'sun_data/sun_10072.npy', 'sun_data/sun_10073.npy', 'sun_data/sun_10074.npy', 'sun_data/sun_10075.npy', 'sun_data/sun_10076.npy', 'sun_data/sun_10077.npy', 'sun_data/sun_10078.npy', 'sun_data/sun_10079.npy', 'sun_data/sun_1008.npy', 'sun_data/sun_10080.npy', 'sun_data/sun_10081.npy', 'sun_data/sun_10082.npy', 'sun_data/sun_10083.npy', 'sun_data/sun_10084.npy', 'sun_data/sun_10085.npy', 'sun_data/sun_10086.npy', 'sun_data/sun_10087.npy', 'sun_data/sun_10088.npy', 'sun_data/sun_10089.npy', 'sun_data/sun_1009.npy', 'sun_data/sun_10090.npy', 'sun_data/sun_10091.npy', 'sun_data/sun_10092.npy', 'sun_data/sun_10093.npy', 'sun_data/sun_10094.npy', 'sun_data/sun_10095.npy', 'sun_data/sun_10096.npy', 'sun_data/sun_10097.npy', 'sun_data/sun_10098.npy', 'sun_data/sun_10099.npy', 'sun_data/sun_101.npy', 'sun_data/sun_1010.npy', 'sun_data/sun_10100.npy', 'sun_data/sun_10101.npy', 'sun_data/sun_10102.npy', 'sun_data/sun_10103.npy', 'sun_data/sun_10104.npy', 'sun_data/sun_10105.npy', 'sun_data/sun_10106.npy', 'sun_data/sun_10107.npy', 'sun_data/sun_10108.npy', 'sun_data/sun_10109.npy', 'sun_data/sun_1011.npy', 'sun_data/sun_10110.npy', 'sun_data/sun_10111.npy', 'sun_data/sun_10112.npy', 'sun_data/sun_10113.npy', 'sun_data/sun_10114.npy', 'sun_data/sun_10115.npy', 'sun_data/sun_10116.npy', 'sun_data/sun_10117.npy', 'sun_data/sun_10118.npy', 'sun_data/sun_10119.npy', 'sun_data/sun_1012.npy', 'sun_data/sun_10120.npy', 'sun_data/sun_10121.npy', 'sun_data/sun_10122.npy', 'sun_data/sun_10123.npy', 'sun_data/sun_10124.npy', 'sun_data/sun_10125.npy', 'sun_data/sun_10126.npy', 'sun_data/sun_10127.npy', 'sun_data/sun_10128.npy', 'sun_data/sun_10129.npy', 'sun_data/sun_1013.npy', 'sun_data/sun_10130.npy', 'sun_data/sun_10131.npy', 'sun_data/sun_10132.npy', 'sun_data/sun_10133.npy', 'sun_data/sun_10134.npy', 'sun_data/sun_10135.npy' ...

# %%
raw_data = [np.load(f'sun_data/sun_{i}.npy', allow_pickle=True).tolist() for i in range(21000)]

# %%
vis = np.array([d['corr01'] for d in raw_data])[:, 400:900]
times = np.array([d['time'] for d in raw_data])
acc_cnt = np.array([d['acc_cnt'] for d in raw_data])
LO = 8.75e9 + 1.54e9
freqs = np.linspace(0, 250e6, 1024, endpoint=False) + LO
freqs = freqs[400:900]

# %%
np.diff(acc_cnt)[np.where(np.diff(acc_cnt) != 1)]
# Out:
# array([ 7,  2, 13,  2,  3,  2,  6,  2,  7,  4,  2,  4,  2,  2,  2])

# %%
vis -= np.mean(vis, axis=0, keepdims=True)

# %%
plt.figure(figsize=(8,20))
plt.imshow(np.angle(vis), interpolation='nearest', aspect='auto')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure()
plt.plot(times, vis[:,200].real)
plt.plot(times, vis[:,200].imag)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
v = vis[:,200]
fq = freqs[200]
v.shape
# Out:
# (21000,)

# %%
v.shape = (-1, 100)
fringe_fq = np.fft.fft(v, axis=1)

# %%
plt.figure()
plt.imshow(np.abs(fringe_fq)**2, interpolation='nearest', aspect='auto', cmap='Spectral')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
C * (freqs[1] - freqs[0]) / freqs[0]
# Out:
# 7094.076469873664

# %%
print(times.shape)
jds_data = ugradio.timing.julian_date(times)
lst0 = ugradio.timing.lst(jds_data[0])
lst1 = ugradio.timing.lst(jds_data[1])
lsts = lst0 + np.arange(jds_data.shape[0]) * (lst1 - lst0)
ones = np.ones_like(lsts)
#ha = lsts - radec[0]
rot_eq_ha = np.array([[
    [np.cos(lsts),  np.sin(lsts),     0*ones],
    [np.sin(lsts), -np.cos(lsts),     0*ones],
    [      0*ones,        0*ones,     1*ones],
]])
lat = np.deg2rad(ugradio.nch.lat)
rot_ha_altaz = np.array([[
    [-np.sin(lat),  0, np.cos(lat)],
    [           0, -1,           0],
    [ np.cos(lat),  0, np.sin(lat)],
]])

rot_full = np.dot(rot_ha_altaz, rot_eq_ha)
rot_full.shape = (3, 3, -1)
# Out:
# (21000,)
# (3, 3, 21000)

# %%
sun_radec = ugradio.coord.sunpos(jds_data[0])
radec = (np.deg2rad(sun_radec[0]), np.deg2rad(sun_radec[1]))
theta = np.pi/2 - radec[1]
phi = radec[0]
sun_z = np.cos(theta)
r_xy = np.sin(theta)
sun_x = r_xy * np.cos(phi)
sun_y = r_xy * np.sin(phi)
sun_pos_eq = np.array([sun_x, sun_y, sun_z])
sun_pos_top = np.dot(sun_pos_eq, rot_full)
print(sun_pos_top.shape)
sun_pos_top = np.array([sun_pos_top[1], sun_pos_top[0], sun_pos_top[2]])
sun_pos_top.shape
# Out:
# (3, 21000)
# (3, 21000)

# %%
baseline = np.array([60., 2, 0])
b_proj = np.dot(baseline, sun_pos_top)
lam = C / fq
w = b_proj / lam
fringe = np.exp(-2*np.pi*1j*w)
fringe = np.where(sun_pos_top[2] > 0, fringe, 0)
print(w.shape)
# Out:
# (21000,)

# %%
plt.figure()
v = vis[:300, 200]
v -= np.mean(v)
plt.plot(v.real)
plt.plot(fringe[:300].real)
plt.plot(v * np.conj(fringe[:300]))
#plt.plot(jds_data, vis[:, 200].real)
#plt.plot(jds_data, w.real)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/aparsons/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
